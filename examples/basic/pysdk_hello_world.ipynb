# %% [markdown]
# ### Get Started with DeGirum PySDK in Google Colab!
# Welcome to the DeGirum PySDK Quickstart Colab! This notebook is designed to help you get started with PySDK right away, without the need to set up tools or dependencies on your local machine. While the Colab environment may not provide the full range of PySDK’s functionality, the included examples will give you a solid understanding of its capabilities. If you’d like to explore the complete features and unlock the full potential of PySDK, we encourage you to install it on your own machine. Let’s get started by installing the `degirum` and `degirum_tools` packages!

# %%
# %pip install degirum
# %pip install degirum_tools
# Out:
# Collecting degirum
#   Downloading degirum-0.16.2-cp311-cp311-manylinux_2_31_x86_64.whl.metadata (1.2 kB)
# Collecting pyzmq>=26.1 (from degirum)
#   Downloading pyzmq-26.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting psutil>=6.0 (from degirum)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyseccomp>=0.1 (from degirum)
#   Downloading pyseccomp-0.1.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: msgpack<2.0,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from degirum) (1.1.0)
# Collecting msgpack-numpy==0.4.7.1 (from degirum)
#   Downloading msgpack_numpy-0.4.7.1-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting numpy<2.0,>=1.22 (from degirum)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python<5.0,>=4.6 in /usr/local/lib/python3.11/dist-packages (from degirum) (4.11.0.86)
# Collecting pillow<11.0,>=9.2 (from degirum)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting python-socketio<6.0,>=5.7 (from python-socketio[client]<6.0,>=5.7->degirum)
#   Downloading python_socketio-5.13.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from degirum) (6.0.2)
# Collecting types-PyYAML<7.0,>=6.0 (from degirum)
#   Downloading types_pyyaml-6.0.12.20250402-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: requests<3.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from degirum) (2.32.3)
# Collecting types-requests<3.0,>=2.30.0 (from degirum)
#   Downloading types_requests-2.32.0.20250328-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from degirum) (1.8.0)
# Collecting bidict>=0.21.0 (from python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-engineio>=4.11.0 (from python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum)
#   Downloading python_engineio-4.12.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (2025.4.26)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum)
#   Downloading simple_websocket-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum) (0.16.0)
# Downloading degirum-0.16.2-cp311-cp311-manylinux_2_31_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 50.2 MB/s eta 0:00:00
# Downloading msgpack_numpy-0.4.7.1-py2.py3-none-any.whl (6.7 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 57.2 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 59.8 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 16.0 MB/s eta 0:00:00
# Downloading pyseccomp-0.1.2-py3-none-any.whl (5.7 kB)
# Downloading python_socketio-5.13.0-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 3.9 MB/s eta 0:00:00
# Downloading pyzmq-26.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.4/862.4 kB 31.8 MB/s eta 0:00:00
# Downloading types_pyyaml-6.0.12.20250402-py3-none-any.whl (20 kB)
# Downloading types_requests-2.32.0.20250328-py3-none-any.whl (20 kB)
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading python_engineio-4.12.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 3.7 MB/s eta 0:00:00
# Downloading simple_websocket-1.1.0-py3-none-any.whl (13 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, types-requests, types-PyYAML, pyzmq, pyseccomp, psutil, pillow, numpy, bidict, simple-websocket, msgpack-numpy, python-engineio, python-socketio, degirum
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 24.0.1
#     Uninstalling pyzmq-24.0.1:
#       Successfully uninstalled pyzmq-24.0.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.2.1
#     Uninstalling pillow-11.2.1:
#       Successfully uninstalled pillow-11.2.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed bidict-0.23.1 degirum-0.16.2 msgpack-numpy-0.4.7.1 numpy-1.26.4 pillow-10.4.0 psutil-7.0.0 pyseccomp-0.1.2 python-engineio-4.12.1 python-socketio-5.13.0 pyzmq-26.4.0 simple-websocket-1.1.0 types-PyYAML-6.0.12.20250402 types-requests-2.32.0.20250328 wsproto-1.2.0
# Collecting degirum_tools
#   Downloading degirum_tools-0.16.6-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (1.15.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (10.4.0)
# Collecting python-dotenv (from degirum_tools)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (2.32.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (7.0.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (4.11.0.86)
# Requirement already satisfied: degirum>=0.16.2 in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (0.16.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (7.34.0)
# Collecting pafy (from degirum_tools)
#   Downloading pafy-0.5.5-py2.py3-none-any.whl.metadata (10 kB)
# Collecting youtube-dl==2020.12.2 (from degirum_tools)
#   Downloading youtube_dl-2020.12.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (2.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (6.0.2)
# Collecting ffmpegcv>=0.3.15 (from degirum_tools)
#   Downloading ffmpegcv-0.3.18-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (4.13.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (4.23.0)
# Collecting apprise (from degirum_tools)
#   Downloading apprise-1.9.3-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=26.1 in /usr/local/lib/python3.11/dist-packages (from degirum>=0.16.2->degirum_tools) (26.4.0)
# Requirement already satisfied: pyseccomp>=0.1 in /usr/local/lib/python3.11/dist-packages (from degirum>=0.16.2->degirum_tools) (0.1.2)
# Requirement already satisfied: msgpack<2.0,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from degirum>=0.16.2->degirum_tools) (1.1.0)
# Requirement already satisfied: msgpack-numpy==0.4.7.1 in /usr/local/lib/python3.11/dist-packages (from degirum>=0.16.2->degirum_tools) (0.4.7.1)
# Requirement already satisfied: python-socketio<6.0,>=5.7 in /usr/local/lib/python3.11/dist-packages (from python-socketio[client]<6.0,>=5.7->degirum>=0.16.2->degirum_tools) (5.13.0)
# Requirement already satisfied: types-PyYAML<7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from degirum>=0.16.2->degirum_tools) (6.0.12.20250402)
# Requirement already satisfied: types-requests<3.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from degirum>=0.16.2->degirum_tools) (2.32.0.20250328)
# Requirement already satisfied: websocket-client<2.0,>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from degirum>=0.16.2->degirum_tools) (1.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->degirum_tools) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->degirum_tools) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->degirum_tools) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->degirum_tools) (2025.4.26)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from apprise->degirum_tools) (2.0.0)
# Requirement already satisfied: click>=5.0 in /usr/local/lib/python3.11/dist-packages (from apprise->degirum_tools) (8.1.8)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from apprise->degirum_tools) (3.8)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (75.2.0)
# Collecting jedi>=0.16 (from ipython->degirum_tools)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (0.24.0)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools->degirum_tools) (3.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->degirum_tools) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (2.9.0.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->degirum_tools) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->degirum_tools) (0.2.13)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum>=0.16.2->degirum_tools) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum>=0.16.2->degirum_tools) (4.12.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib->apprise->degirum_tools) (3.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools->degirum_tools) (1.17.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum>=0.16.2->degirum_tools) (1.1.0)
# Requirement already satisfied: wsproto in /usr/local/lib/python3.11/dist-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum>=0.16.2->degirum_tools) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum>=0.16.2->degirum_tools) (0.16.0)
# Downloading degirum_tools-0.16.6-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.0/141.0 kB 883.7 kB/s eta 0:00:00
# Downloading youtube_dl-2020.12.2-py2.py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.7 MB/s eta 0:00:00
# Downloading ffmpegcv-0.3.18-py3-none-any.whl (32 kB)
# Downloading apprise-1.9.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 54.3 MB/s eta 0:00:00
# Downloading pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.6 MB/s eta 0:00:00
# Installing collected packages: youtube-dl, pafy, python-dotenv, jedi, ffmpegcv, apprise, degirum_tools
# Successfully installed apprise-1.9.3 degirum_tools-0.16.6 ffmpegcv-0.3.18 jedi-0.19.2 pafy-0.5.5 python-dotenv-1.1.0 youtube-dl-2020.12.2

# %% [markdown]
# ### Setting the token
# Since we’ll be using hardware hosted in the cloud by DeGirum, you’ll need to set a token to access these resources. This token serves as your secure key to connect to DeGirum’s cloud infrastructure and enables you to run the examples provided in this notebook seamlessly.
#
# To guide you through the process of obtaining your token and adding it as a new secret in Google Colab, refer to the videos below:
#
# [![Generating a Token for the DeGirum AI Hub](https://img.youtube.com/vi/iyii0RzyFm8/0.jpg)](https://youtu.be/iyii0RzyFm8)
# [![How to Add a New Secret in Google Colab](https://img.youtube.com/vi/GmevDVlT0OQ/0.jpg)](https://youtu.be/GmevDVlT0OQ)
#
# *Click on the thumbnail to watch the tutorial video.*

# %% [markdown]
# You may verify your token with this code:

# %%
import degirum_tools
# print cloud token
degirum_tools.get_token()
# Out:
# 'dg_7nechpWiT4T2RCPazthXJHp1HmznnU2F8V31h'

# %% [markdown]
# ### Running Your First Inference
#
# In this section, we’ll demonstrate how to use PySDK to perform object detection on an example image using a cloud-hosted AI model. Here’s what the code does:
#
# 1. **Import Required Libraries**: The `degirum` package is used for loading and using AI models, and `degirum_tools` provides utility functions such as obtaining a token and displaying results.
#
# 2. **Load the Object Detection Model**: The `degirum.load_model()` method loads a pre-trained YOLOv8 object detection model hosted in the DeGirum cloud. The key parameters here are:
#    - `model_name`: Specifies the AI model to use.
#    - `inference_host_address`: Indicates where inference will be performed. Setting it to `"@cloud"` connects the request to DeGirum’s cloud-hosted hardware, leveraging powerful compute resources without requiring local setup. For on-premise or local deployments, this value can be replaced with the IP address or hostname of the target device.
#    - `zoo_url`: Defines the location of the model zoo, a repository of pre-trained AI models. In this example, it is set to `'degirum/models_hailort'`, specifying a cloud-hosted model zoo managed by DeGirum. The `zoo_url` format typically follows `<organization>/<model_zoo_name>` and can be customized for private repositories.
#    - `token`: Authenticates your access to the cloud-hosted resources, retrieved here using `degirum_tools.get_token()`.
#
# 3. **Run Inference on an Image**: The model processes an example image (a URL pointing to an example image) and generates detection results.
#
# 4. **Display the Results**: The numeric results of the inference, including detected bounding boxes and class IDs, are printed to the console. Additionally, using `degirum_tools.Display`, the inference results are visualized with object overlays on the input image.
#
# When you run this code, you should see hardware hosted on the cloud run an object classification model, identify detected objects, and show bounding boxes for those detected objects with only a few lines of code.

# %%
import degirum as dg, degirum_tools

# load object detection AI model
model = dg.load_model(
    model_name="yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1",
    inference_host_address="@cloud",
    zoo_url='degirum/models_hailort',
    token=degirum_tools.get_token(),
)

# perform AI model inference on given image source
inference_result = model("https://raw.githubusercontent.com/DeGirum/PySDKExamples/main/images/bikes.jpg")

# show results of inference
print(inference_result)  # numeric results
with degirum_tools.Display() as display:
    display.show_image(inference_result)
# Out:
# - bbox: [210.86090087890625, 270.1266174316406, 331.5318908691406, 361.11517333984375]
#   category_id: 1
#   label: bicycle
#   score: 0.7735219597816467
# - bbox: [355.7708740234375, 260.1676940917969, 415.4579162597656, 364.5289306640625]
#   category_id: 0
#   label: person
#   score: 0.7070766091346741
# - bbox: [55.89934539794922, 275.9025573730469, 177.1614227294922, 363.0513000488281]
#   category_id: 1
#   label: bicycle
#   score: 0.7006438970565796
# - bbox: [354.98675537109375, 291.8433837890625, 523.98828125, 367.9513244628906]
#   category_id: 13
#   label: bench
#   score: 0.7006438970565796
# - bbox: [426.5059509277344, 258.5829162597656, 473.8647155761719, 357.20672607421875]
#   category_id: 0
#   label: person
#   score: 0.5488012433052063
# <PIL.Image.Image image mode=RGB size=640x424>

# %% [markdown]
# ### Unified AI Inference with DeGirum PySDK
# We will now highlight the core capabilities of PySDK, showcasing its flexibility and simplicity in deploying AI models across multiple hardware platforms. By specifying the appropriate model name and model zoo, you can seamlessly run different types of models, such as classification, detection, keypoint detection, or segmentation, using the same unified interface. The JSON configuration provided in the code below enables you to select the hardware you want to use for the AI task you want to perform. We assign a model zoo URL as well as the model names from the DeGirum AI Hub for each AI task. Our approach abstracts hardware-specific complexities, driving a consistent experience for diverse AI tasks.
#
# In the code below, `degirum_tools.Display`, overlays an intuitive visualization of the model's inference results on the input image. This example underscores PySDK’s design philosophy: different models, same code, unified visualization.

# %%
import ipywidgets as widgets
from IPython.display import display
import degirum as dg, degirum_tools

# Define configurations
model_configurations = {
    "Hailo": {
        "zoo_url": "degirum/models_hailort",
        "model_names": {
            "classification": ["yolov8s_silu_imagenet--224x224_quant_hailort_hailo8_1"],
            "detection": ["yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1"],
            "keypoint_detection": ["yolov8n_relu6_widerface_kpts--640x640_quant_hailort_hailo8_1"],
            "segmentation": ["yolov8n_relu6_coco_seg--640x640_quant_hailort_hailo8_1"],
        },
    },
    "Google": {
        "zoo_url": "degirum/models_tflite",
        "model_names": {
            "classification": ["yolov8s_silu_imagenet--224x224_quant_tflite_edgetpu_1"],
            "detection": ["yolov8n_relu6_coco--640x640_quant_tflite_edgetpu_1"],
            "keypoint_detection": ["yolov8n_relu6_widerface_kpts--640x640_quant_tflite_edgetpu_1"],
            "segmentation": ["yolov8n_relu6_coco_seg--640x640_quant_tflite_edgetpu_1"],
        },
    },
    "Intel": {
        "zoo_url": "degirum/models_openvino",
        "model_names": {
            "classification": ["yolov8s_silu_imagenet--224x224_float_openvino_multidevice_1"],
            "detection": ["yolov8n_relu6_coco--640x640_float_openvino_multidevice_1"],
            "keypoint_detection": ["yolov8n_relu6_widerface_kpts--640x640_float_openvino_multidevice_1"],
            "segmentation": ["yolov8n_relu6_coco_seg--640x640_float_openvino_multidevice_1"],
        },
    },
    "DeGirum": {
        "zoo_url": "degirum/models_n2x",
        "model_names": {
            "classification": ["yolov8s_silu_imagenet--224x224_quant_n2x_orca1_1"],
            "detection": ["yolov8n_relu6_coco--640x640_quant_n2x_orca1_1"],
            "keypoint_detection": ["yolov8n_relu6_widerface_kpts--640x640_quant_n2x_orca1_1"],
            "segmentation": ["yolov8n_relu6_coco_seg--640x640_quant_n2x_orca1_1"],
        },
    },
    "RockChip": {
        "zoo_url": "degirum/models_rknn",
        "model_names": {
            "classification": ["yolov8s_silu_imagenet--224x224_quant_rknn_rk3588_1"],
            "detection": ["yolov8n_relu6_coco--640x640_quant_rknn_rk3588_1"],
            "keypoint_detection": ["yolov8n_relu6_widerface_kpts--640x640_quant_rknn_rk3588_1"],
            "segmentation": ["yolov8n_relu6_coco_seg--640x640_quant_rknn_rk3588_1"],
        },
    },
}

source_images = {
    "classification": "https://raw.githubusercontent.com/DeGirum/PySDKExamples/main/images/Cat.jpg",
    "detection": "https://raw.githubusercontent.com/DeGirum/PySDKExamples/main/images/bikes.jpg",
    "keypoint_detection": "https://raw.githubusercontent.com/DeGirum/PySDKExamples/main/images/Mask1.jpg",
    "segmentation": "https://raw.githubusercontent.com/DeGirum/PySDKExamples/main/images/ThreePersons.jpg",
}

# Create widgets
hardware_dropdown = widgets.Dropdown(
    options=model_configurations.keys(),
    value="Hailo",
    description="Hardware:",
)

model_type_dropdown = widgets.Dropdown(
    options=list(source_images.keys()),
    value="detection",
    description="Model Type:",
)

run_button = widgets.Button(
    description="Run Inference",
    button_style="success",  # Optional: 'success', 'info', 'warning', 'danger'
)

output = widgets.Output()

# Define the inference function
def run_inference(button_click):
    with output:
        output.clear_output()  # Clear previous output
        hardware_option = hardware_dropdown.value
        model_type = model_type_dropdown.value

        inference_host_address = "@cloud"
        zoo_url = model_configurations[hardware_option]["zoo_url"]
        model_name = model_configurations[hardware_option]["model_names"][model_type][0]
        source_image = source_images[model_type]

        print(f"Running inference on hardware: {hardware_option}")
        print(f"Model type: {model_type}")
        print(f"Model name: {model_name}")

        # Load and run inference
        model = dg.load_model(
            model_name=model_name,
            inference_host_address=inference_host_address,
            zoo_url=zoo_url,
            token=degirum_tools.get_token()
        )
        inference_result = model(source_image)

        print("Inference result:")
        print(inference_result)
        with degirum_tools.Display() as display:
            display.show_image(inference_result)

# Link the Run button to the inference function
run_button.on_click(run_inference)

# Display widgets and output
display(hardware_dropdown, model_type_dropdown, run_button, output)
# Out:
# Dropdown(description='Hardware:', options=('Hailo', 'Google', 'Intel', 'DeGirum', 'RockChip'), value='Hailo')
# Dropdown(description='Model Type:', index=1, options=('classification', 'detection', 'keypoint_detection', 'se…
# Button(button_style='success', description='Run Inference', style=ButtonStyle())
# Output()

# %% [markdown]
# ### Explore and Experiment with DeGirum PySDK
#
# This example demonstrates how to perform AI inference using PySDK with a pre-trained model hosted in the cloud. We encourage you to experiment further by trying out different **model zoos**, **model names**, and **image sources**. For instance, you can explore various AI tasks such as object detection, classification, keypoint detection, or segmentation by selecting models from different model zoos (e.g., `models_hailort`, `models_tflite`, `models_openvino`, etc.) and providing images of your choice. This flexibility showcases PySDK's unified API, allowing you to customize and test AI inference across multiple hardware platforms and tasks effortlessly. Dive in and discover the possibilities!

# %%
import degirum as dg, degirum_tools

hw_location = "@cloud" # "@cloud" for cloud inference, "@local" for local inference, or IP address for AI server inference
model_zoo_url = "degirum/models_hailort" # models_hailort, models_tflite, models_openvino, models_n2x, models_rknn
model_name = "yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1"
image_source = "https://raw.githubusercontent.com/DeGirum/PySDKExamples/main/images/Mask1.jpg"

# load object detection AI model
model = dg.load_model(
    model_name=model_name,
    inference_host_address=hw_location,
    zoo_url=model_zoo_url,
    token=degirum_tools.get_token()
)

# perform AI model inference on given image source
inference_result = model(image_source)

# show results of inference
print(inference_result)  # numeric results
with degirum_tools.Display() as display:
    display.show_image(inference_result)
# Out:
# - bbox: [405.41181564331055, 2.5621533393859863, 765.0625705718994, 497.0569324493408]
#   category_id: 0
#   label: person
#   score: 0.9337382316589355
# - bbox: [109.56999778747559, 30.099492073059082, 439.4066905975342, 494.71208095550537]
#   category_id: 0
#   label: person
#   score: 0.9138933420181274
# - bbox: [1.3101249933242798, 190.77428340911865, 82.24784195423126, 290.0325393676758]
#   category_id: 2
#   label: car
#   score: 0.7459365129470825
# - bbox: [746.1191368103027, 179.25408840179443, 899.725513458252, 373.51404190063477]
#   category_id: 2
#   label: car
#   score: 0.5966814756393433
# - bbox: [81.35213434696198, 196.28113746643066, 141.15734338760376, 254.002103805542]
#   category_id: 2
#   label: car
#   score: 0.592937707901001
# - bbox: [155.01419305801392, 168.20244312286377, 204.0243101119995, 251.89453125]
#   category_id: 0
#   label: person
#   score: 0.3002144694328308
# <PIL.Image.Image image mode=RGB size=900x500>
